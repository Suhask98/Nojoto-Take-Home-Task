# %%
import pandas as pd
import numpy as np
df = pd.read_excel(r'C:\Users\91901\Downloads\RAW Data with 2 Sheets.xlsx', sheet_name = 'RAW Data 1 For Conversion Rate')
df.head()
# Out:
#   Start Date   End Date Portfolio name Currency                 Campaign Name  \
# 0 2021-02-01 2021-02-24      swades_is      USD  Project Swades TEST Dec 2020
# 1 2021-02-01 2021-02-24      swades_is      USD  Project Swades TEST Dec 2020
# 2 2021-02-01 2021-02-24      swades_is      USD  Project Swades TEST Dec 2020
# 3 2021-02-03 2021-02-24      swades_is      USD                auto_is_san_90
# 4 2021-02-10 2021-02-24      swades_is      USD        brh_is_man_products_p1
#
#             Ad Group Name  Advertised SKU Advertised ASIN  Impressions  \
# 0              Ad group 1  BRH_INS_LAV_90      B08RBXJ635       173519
# 1              Ad group 1  BRH_INS_SAN_90      B08RBXKCV1        99971
# 2              Ad group 1  BRH_INS_EUC_90      B08RBT5W8Q       148133
# 3          auto_is_san_90  BRH_INS_SAN_90      B08RBXKCV1        37629
# 4  brh_is_man_products_p1  BRH_INS_LAV_90      B08RBXJ635       105411
#
# ...

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 23 columns):
# Start Date                                  69 non-null datetime64[ns]
# End Date                                    69 non-null datetime64[ns]
# Portfolio name                              69 non-null object
# Currency                                    69 non-null object
# Campaign Name                               69 non-null object
# Ad Group Name                               69 non-null object
# Advertised SKU                              69 non-null object
# Advertised ASIN                             69 non-null object
# Impressions                                 69 non-null int64
# Clicks                                      69 non-null int64
# Click-Thru Rate (CTR)                       69 non-null float64
# Cost Per Click (CPC)                        50 non-null float64
# Spend                                       69 non-null float64
# ...

# %%
df.tail()
# Out:
#    Start Date   End Date Portfolio name Currency            Campaign Name  \
# 64 2021-02-16 2021-02-24      swades_is      USD        brh_is_man_pt_euc
# 65 2021-02-17 2021-02-23      swades_is      USD       is_global_all_skus
# 66 2021-02-18 2021-02-24      swades_is      USD  brh_is_comp_karmaScents
# 67 2021-02-19 2021-02-24      swades_is      USD           brh_man_is_yog
# 68 2021-02-22 2021-02-24      swades_is      USD        brh_is_man_pt_ros
#
#                 Ad Group Name  Advertised SKU Advertised ASIN  Impressions  \
# 64          brh_is_man_pt_euc  BRH_INS_EUC_90      B08RBT5W8Q           99
# 65  is_global_all_skus_phrase  BRH_INS_ROS_90      B08RBX526C          323
# 66    brh_is_comp_karmaScents  BRH_INS_ROS_90      B08RBX526C          195
# 67       brh_man_is_yog_broad  BRH_INS_EUC_90      B08RBT5W8Q          104
# 68                 Ad group 1  BRH_INS_ROS_90      B08RBX526C            7
#
# ...

# %%
df.pivot_table(index = ['Currency'],
               columns = 'Portfolio name', 
               values = 'Clicks')
# Out:
# Portfolio name  Not grouped     swades_is
# Currency
# USD                 5234.75  22368.229508

# %%
df.pivot_table(index = ['Campaign Name'],
               columns = 'Portfolio name', 
               values = 'Impressions')
# Out:
# Portfolio name                 Not grouped  swades_is
# Campaign Name
# AE_Product_Targeting                  96.0        NaN
# AE_brush_auto_KT                   12956.0        NaN
# AE_brush_giftHoliday                 163.0        NaN
# Ae_manual_broad                      427.0        NaN
# Ae_manual_phrase                    2208.0        NaN
# CC Amazon US                          11.0        NaN
# Project Swades TEST Dec 2020           NaN   113698.4
# ae_bsb_auto_alpha_1                25011.0        NaN
# auto_is_euc_90                         NaN    24472.0
# auto_is_lav_90                         NaN    35334.0
# auto_is_nagc_90                        NaN    42800.0
# auto_is_ros_90                         NaN    34115.0
# auto_is_san_90                         NaN    37629.0
# brh_is_comp_karmaScents                NaN      897.6
# brh_is_man_bath                        NaN        2.0
# brh_is_man_eo_general                  NaN        3.5
# ...

# %%
df.pivot_table(index = ['Ad Group Name'],
               columns = 'Advertised SKU', 
               values = 'Spend')
# Out:
# Advertised SKU                        AE_HHSB_M001_1106E  BRH_INS_EUC_90  \
# Ad Group Name
# Ad group 1                                         3.916          43.685
# ae_bsb_auto_alpha_1                               17.110             NaN
# auto_is_euc_90                                       NaN          21.060
# auto_is_lav_90                                       NaN             NaN
# auto_is_nagc_90                                      NaN             NaN
# auto_is_ros_90                                       NaN             NaN
# auto_is_san_90                                       NaN             NaN
# brh_is_comp_karmaScents                              NaN           5.640
# brh_is_man_bath_broad                                NaN             NaN
# brh_is_man_eo_general_broad                          NaN           0.000
# brh_is_man_euc_eo_broad                              NaN           0.000
# brh_is_man_euc_phrase                                NaN          10.190
# ...

# %%
df.pivot_table(index = 'Advertised SKU', 
               columns = 'Portfolio name',
               values = '7 Day Advertised SKU Sales ')
# Out:
# Portfolio name      Not grouped  swades_is
# Advertised SKU
# AE_HHSB_M001_1106E          0.0        NaN
# BRH_INS_EUC_90              NaN  14.040000
# BRH_INS_LAV_90              NaN  34.020000
# BRH_INS_NAGC_90             NaN  14.342000
# BRH_INS_ROS_90              NaN  20.102727
# BRH_INS_SAN_90              NaN  28.036923
# V4-YKF0-7ZJE                0.0        NaN
